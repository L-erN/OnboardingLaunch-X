# %% [markdown]
# Ejercicio1 - Utilizar operadores aritméticos

# %%
tierra = 149597870
jupiter = 778547200

# %%
distancia = abs(tierra - jupiter)
distancia2 = round(distancia*0.621)
print("{}\n{}".format(distancia, distancia2))
# Out:
# 628949330
# 390577534

# %% [markdown]
# Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %%
planeta1 = input('Escribe la distancia al sol de tu planeta')
planeta2 = input('Escribe la distancia al sol de tu planeta')

# %%
planeta_1 = int(planeta1)
planeta_2 = int(planeta2)

# %%
distancia = abs(planeta_1-planeta_2)
distanciaMillas = distancia * 0.621

print(distanciaMillas)
# Out:
# 2

# %% [markdown]
# Curso Propedútico de Python para Launch X - Innovacción Virtual.
